# %%
# timm のみダウンロード（依存関係はKaggle環境のものを使う）
# !pip download --no-deps -d /kaggle/working timm

# ダウンロードした .whl をインストール
# !pip install /kaggle/working/*.whl \
    --force-reinstall \
    --root-user-action ignore \
    --no-deps \
    --no-index \
    --find-links /kaggle/working

# バージョン確認
# !python -c "import timm; print(f'timm: {timm.__version__}')"
# !ls /kaggle/working
